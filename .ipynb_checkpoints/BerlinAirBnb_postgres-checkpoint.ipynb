# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
listings = "listings.csv"
listings_data_df = pd.read_csv(listings)
listings_data_df.head()
# Out:
#      id                                              name  host_id host_name  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central     2217       Ian
# 1  2695                Prenzlauer Berg close to Mauerpark     2986   Michael
# 2  3176                   Fabulous Flat in great Location     3718    Britta
# 3  3309                 BerlinSpot Schöneberg near KaDeWe     4108      Jana
# 4  7071                  BrightRoom with sunny greenview!    17391    Bright
#
#       neighbourhood_group             neighbourhood   latitude  longitude  \
# 0                   Mitte           Brunnenstr. Süd  52.534537  13.402557
# 1                  Pankow  Prenzlauer Berg Nordwest  52.548513  13.404553
# 2                  Pankow   Prenzlauer Berg Südwest  52.534996  13.417579
# 3  Tempelhof - Schöneberg           Schöneberg-Nord  52.498855  13.349065
# 4                  Pankow            Helmholtzplatz  52.543157  13.415091
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt     60               4                118  2018-10-28
# 1     Private room     17               2                  6  2018-10-01
# 2  Entire home/apt     90              62                143  2017-03-20
# 3     Private room     26               5                 25  2018-08-16
# 4     Private room     42               2                197  2018-11-04
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               3.76                               4               141
# 1               1.42                               1                 0
# 2               1.25                               1               220
# 3               0.39                               1               297
# 4               1.75                               1                26

# %%
new_listings_data_df = listings_data_df[['id', 'name', 'neighbourhood', 'price']].copy()
new_listings_data_df.head()
# Out:
#      id                                              name  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central
# 1  2695                Prenzlauer Berg close to Mauerpark
# 2  3176                   Fabulous Flat in great Location
# 3  3309                 BerlinSpot Schöneberg near KaDeWe
# 4  7071                  BrightRoom with sunny greenview!
#
#               neighbourhood  price
# 0           Brunnenstr. Süd     60
# 1  Prenzlauer Berg Nordwest     17
# 2   Prenzlauer Berg Südwest     90
# 3           Schöneberg-Nord     26
# 4            Helmholtzplatz     42

# %%
reviews = "reviews_summary.csv"
reviews_data_df = pd.read_csv(reviews)
reviews_data_df.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0        2015  69544350  2016-04-11      7178145         Rahel
# 1        2015  69990732  2016-04-15     41944715        Hannah
# 2        2015  71605267  2016-04-26     30048708        Victor
# 3        2015  73819566  2016-05-10     63697857          Judy
# 4        2015  74293504  2016-05-14     10414887        Romina
#
#                                             comments
# 0  Mein Freund und ich hatten gute gemütliche vie...
# 1  Jan was very friendly and welcoming host! The ...
# 2  Un appartement tres bien situé dans un quartie...
# 3  It is really nice area, food, park, transport ...
# 4  Buena ubicación, el departamento no está orden...

# %%
new_reviews_data_df = reviews_data_df[['listing_id', 'comments']].copy()
new_reviews_data_df.head()
# Out:
#    listing_id                                           comments
# 0        2015  Mein Freund und ich hatten gute gemütliche vie...
# 1        2015  Jan was very friendly and welcoming host! The ...
# 2        2015  Un appartement tres bien situé dans un quartie...
# 3        2015  It is really nice area, food, park, transport ...
# 4        2015  Buena ubicación, el departamento no está orden...

# %%
new_reviews_data_df.rename(columns={'listing_id':'id'}, inplace=True)
new_reviews_data_df.head()
# Out:
#      id                                           comments
# 0  2015  Mein Freund und ich hatten gute gemütliche vie...
# 1  2015  Jan was very friendly and welcoming host! The ...
# 2  2015  Un appartement tres bien situé dans un quartie...
# 3  2015  It is really nice area, food, park, transport ...
# 4  2015  Buena ubicación, el departamento no está orden...

# %%
#new_reviews_data_df.to_csv('comments.csv')

# %%
review_group = new_reviews_data_df.set_index('comments').to_dict()
#review_group
# output appears liek this:
# {'id': {'MeinFreund...':2015,
#Jan was... there a lot!': 2015,... }}

# %%
#postgres connection
rds_connection_string = "postgres:postgres@localhost:5432/berlin_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['listings', 'reviews']

# %%
# Use pandas to load csv converted DataFrame into database 
#new_listings_data_df.to_sql(name='listings', con=engine, if_exists='append', index=False)

# %%
 pd.read_sql_query('select * from listings', con=engine).head()
# Out:
#      id                                              name  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central
# 1  2695                Prenzlauer Berg close to Mauerpark
# 2  3176                   Fabulous Flat in great Location
# 3  3309                 BerlinSpot Schöneberg near KaDeWe
# 4  7071                  BrightRoom with sunny greenview!
#
#               neighbourhood  price
# 0           Brunnenstr. Süd     60
# 1  Prenzlauer Berg Nordwest     17
# 2   Prenzlauer Berg Südwest     90
# 3           Schöneberg-Nord     26
# 4            Helmholtzplatz     42

# %%
#new_reviews_data_df.to_sql(name='reviews', con=engine, if_exists='append', index=True)

# %%
 pd.read_sql_query('select * from reviews', con=engine).head()
# Out:
#    index    id                                           comments
# 0      0  2015  Mein Freund und ich hatten gute gemütliche vie...
# 1      1  2015  Jan was very friendly and welcoming host! The ...
# 2      2  2015  Un appartement tres bien situé dans un quartie...
# 3      3  2015  It is really nice area, food, park, transport ...
# 4      4  2015  Buena ubicación, el departamento no está orden...

# %% [markdown]
# ## making new df with new csv

# %%
comments = "combined_comments.csv"
comments_data_df = pd.read_csv(comments)
comments_data_df.head()
# Out:
#      id                                            results
# 0  2015  {"Small nice flat, perfect for one or two peop...
# 1  2695  {"Super nice and friendly. Great communication...
# 2  3176  {"Location, location, location! Britta's place...
# 3  3309  {"Nice person, nice place, nice stay.","Jana h...
# 4  7071  {"I had a very pleasant stay at Can´s apartmen...

# %%
complete_data_df = pd.concat([new_listings_data_df,comments_data_df],axis=1,join='outer')

# %%
complete_data_df.head()
# Out:
#      id                                              name  \
# 0  2015  Berlin-Mitte Value! Quiet courtyard/very central
# 1  2695                Prenzlauer Berg close to Mauerpark
# 2  3176                   Fabulous Flat in great Location
# 3  3309                 BerlinSpot Schöneberg near KaDeWe
# 4  7071                  BrightRoom with sunny greenview!
#
#               neighbourhood  price      id  \
# 0           Brunnenstr. Süd     60  2015.0
# 1  Prenzlauer Berg Nordwest     17  2695.0
# 2   Prenzlauer Berg Südwest     90  3176.0
# 3           Schöneberg-Nord     26  3309.0
# 4            Helmholtzplatz     42  7071.0
#
#                                              results
# 0  {"Small nice flat, perfect for one or two peop...
# 1  {"Super nice and friendly. Great communication...
# 2  {"Location, location, location! Britta's place...
# 3  {"Nice person, nice place, nice stay.","Jana h...
# 4  {"I had a very pleasant stay at Can´s apartmen...

# %%
clean_complete_data_df = complete_data_df[['id', 'name', 'neighbourhood', 'price', 'results']].copy()
clean_complete_data_df.head()
# Out:
#      id      id                                              name  \
# 0  2015  2015.0  Berlin-Mitte Value! Quiet courtyard/very central
# 1  2695  2695.0                Prenzlauer Berg close to Mauerpark
# 2  3176  3176.0                   Fabulous Flat in great Location
# 3  3309  3309.0                 BerlinSpot Schöneberg near KaDeWe
# 4  7071  7071.0                  BrightRoom with sunny greenview!
#
#               neighbourhood  price  \
# 0           Brunnenstr. Süd     60
# 1  Prenzlauer Berg Nordwest     17
# 2   Prenzlauer Berg Südwest     90
# 3           Schöneberg-Nord     26
# 4            Helmholtzplatz     42
#
#                                              results
# 0  {"Small nice flat, perfect for one or two peop...
# 1  {"Super nice and friendly. Great communication...
# 2  {"Location, location, location! Britta's place...
# 3  {"Nice person, nice place, nice stay.","Jana h...
# 4  {"I had a very pleasant stay at Can´s apartmen...

# %%
clean_complete_data_df.to_csv('finalOutput/complete.csv')
